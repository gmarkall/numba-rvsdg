# %%
from numba_rvsdg import run_frontend

def show_ir(f):
    ir = run_frontend(f)
    return ir.render_dot()

# %%
def example1(x, y):
    if GLOBAL:
        return x
    else:
        return y
    
def example2(x):
    for i in range(len(x)):
        x[i] = x[i] + 1
        
def example3(x):
    condition = True
    while condition:
        if x < 10:
            break
        else:
            x -= 1

# %%
show_ir(example1)

# %%
show_ir(example2)

# %%
show_ir(example3)

# %%
from numba_rvsdg.rendering.rendering import render_func

# %%
render_func(example1)
# Out:
# Opening in existing browser session.
# Opening in existing browser session.
# Opening in existing browser session.
# Opening in existing browser session.

# %%
render_func(example2)
# Out:
# Opening in existing browser session.
# Opening in existing browser session.
# Opening in existing browser session.
# Opening in existing browser session.

# %%
render_func(example3)
# Out:
# Opening in existing browser session.
# Opening in existing browser session.
# Opening in existing browser session.
# Opening in existing browser session.
